# %%
import pandas as pd
import numpy as np
from transformers import pipeline

# %%
reviews = pd.read_csv("data_cleaned.csv")

# %%
reviews.head()
# Out:
#   review_id           product     category  rating  \
# 0  REV14165       TechPro X20  Smartphones       4
# 1  REV81426       TechPro X20  Smartphones       4
# 2  REV54597    SmartWatch Pro    Wearables       4
# 3  REV89131  SmartSpeaker 360   Smart Home       4
# 4  REV92397   HomeConnect Hub   Smart Home       4
#
#                                          review_text     feature_mentioned  \
# 0  The TechPro X20 is amazing! facial recognition...    facial recognition
# 1  The TechPro X20 is amazing! battery life works...          battery life
# 2  The SmartWatch Pro is amazing! app integration...       app integration
# 3  Very impressed with the SmartSpeaker 360. Grea...         app interface
# 4  Very impressed with the HomeConnect Hub. Great...  device compatibility
#
#   attribute_mentioned        date sentiment  \
# 0              design  2023-03-09  positive
# 1              design  2023-10-28  positive
# 2          durability  2023-03-09  positive
# ...

# %%
classifier = pipeline("text-classification",
                      model="chawki17/my_sentiment_model",
                      )
classifier("I love this product")
# Out:
# config.json:   0%|          | 0.00/765 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# Device set to use cuda:0
# [[{'label': 'LABEL_0', 'score': 0.704481840133667},
#   {'label': 'LABEL_1', 'score': 0.17950859665870667},
#   {'label': 'LABEL_2', 'score': 0.11600960791110992}]]

# %%
def get_sentiment(text):
  # Load model
  model_name = "j-hartmann/sentiment-roberta-large-english-3-classes"
  classifier = pipeline("text-classification", model=model_name)
  # Get top prediction
  result = classifier(text)[0]
  return result["label"]

# %%
get_sentiment("It looks okay")
# Out:
# config.json:   0%|          | 0.00/725 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.43G [00:00<?, ?B/s]
# Some weights of the model checkpoint at j-hartmann/sentiment-roberta-large-english-3-classes were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# model.safetensors:   0%|          | 0.00/1.43G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.07k [00:00<?, ?B/s]
# ...

# %%
# Assuming 'reviews' is your DataFrame
reviews['predicted_sentiment'] = reviews['review_text'].apply(get_sentiment)
# Out:
# Some weights of the model checkpoint at j-hartmann/sentiment-roberta-large-english-3-classes were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cuda:0
# Some weights of the model checkpoint at j-hartmann/sentiment-roberta-large-english-3-classes were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# ...

# %%
reviews.head()
# Out:
#   review_id           product     category  rating  \
# 0  REV14165       TechPro X20  Smartphones       4
# 1  REV81426       TechPro X20  Smartphones       4
# 2  REV54597    SmartWatch Pro    Wearables       4
# 3  REV89131  SmartSpeaker 360   Smart Home       4
# 4  REV92397   HomeConnect Hub   Smart Home       4
#
#                                          review_text     feature_mentioned  \
# 0  The TechPro X20 is amazing! facial recognition...    facial recognition
# 1  The TechPro X20 is amazing! battery life works...          battery life
# 2  The SmartWatch Pro is amazing! app integration...       app integration
# 3  Very impressed with the SmartSpeaker 360. Grea...         app interface
# 4  Very impressed with the HomeConnect Hub. Great...  device compatibility
#
#   attribute_mentioned        date sentiment  \
# 0              design  2023-03-09  positive
# 1              design  2023-10-28  positive
# 2          durability  2023-03-09  positive
# ...

# %%
# Compare predicted sentiment with existing sentiment
reviews['comparison'] = reviews['sentiment'] == reviews['predicted_sentiment'].str.lower()

# %%
accuracy = reviews['comparison'].sum() / len(reviews)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.805

# %%
reviews.to_csv("reviews_with_predicted_sentiments.csv", index = False)
